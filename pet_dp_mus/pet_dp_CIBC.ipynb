# %%
import os
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import Sequential, layers
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import numpy as np
from sklearn.metrics import ConfusionMatrixDisplay
import sklearn
from imblearn.under_sampling import RandomUnderSampler
from keras.regularizers import l2
from imblearn.over_sampling import SMOTE
from tensorflow.keras.utils import to_categorical
from scipy import special
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.layers import PReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %%
df = pd.read_csv("/ssd003/projects/pets/datasets/homecredit_train.csv")

# %%
fig, ax = plt.subplots()
df['target'].value_counts().plot(ax=ax, kind='bar')

train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)
train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=42)

# Oversampling target labels
max_size = train_df['target'].value_counts().max()

# lst = [train_df]
# for class_index, group in train_df.groupby('target'):
#     lst.append(group.sample(max_size-len(group), replace=True))
# X_train = pd.concat(lst)

X_train = train_df.drop(['target'], axis=1)
y_train = train_df['target']

rus = SMOTE(random_state=42)
X_train, y_train = rus.fit_resample(X_train, y_train)

X_test = test_df.drop(['target'], axis=1)
y_test = test_df['target']

X_val = val_df.drop(['target'], axis=1)
y_val = val_df['target']

fig, ax = plt.subplots()
y_train.value_counts().plot(ax=ax, kind='bar')

# y_train = np.array(y_train, dtype=np.float32) 
# y_test = np.array(y_test, dtype=np.float32) 
# y_val = np.array(y_val, dtype=np.float32)

# y_train = y_train.flatten()
# y_test = y_test.flatten()
# y_val = y_val.flatten()
# Out:
# <AxesSubplot:>

# %%
scaler = StandardScaler()
X_train_transform = scaler.fit_transform(X_train)
X_val_transform = scaler.transform(X_val)
X_test_transform = scaler.transform(X_test)

X_train_transform = pd.DataFrame(X_train_transform,columns = X_train.columns)
X_val_transform = pd.DataFrame(X_val_transform,columns = X_train.columns)
X_test_transform = pd.DataFrame(X_test_transform, columns = X_train.columns)

X_train_transform = np.clip(X_train_transform, -5, 5)
X_val_transform = np.clip(X_val_transform, -5, 5)
X_test_transform = np.clip(X_test_transform, -5, 5)

# %% [markdown]
# # BASELINE MODEL

# %%
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),
      tf.keras.metrics.AUC(name='auc'),
      tf.keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]


params = {
    "layer1": 400,
    "layer2": 160,
    "layer3": 64,
    "layer4": 26,
    "layer5": 12,
    "epochs": 1000,
    "dropout": 0.3
}

def make_model(logits, last_nodes):
    model = Sequential()
    model.add(Dense(units = params['layer1'] , input_dim = X_train.shape[-1]))
    model.add(PReLU())
    model.add(Dropout(params['dropout']))
    model.add(Dense(units = params['layer2'] ))
    model.add(PReLU())
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout']))
    model.add(Dense(units = params['layer3']))
    model.add(PReLU())
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout']))
    model.add(Dense(units = params['layer4']))
    model.add(PReLU())
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout']))
    model.add(Dense(units = params['layer5'], activation="relu"))
    model.add(PReLU())
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout']))
    if not logits:
        model.add(Dense(last_nodes, activation='sigmoid'))
    else:
        model.add(Dense(last_nodes))    
    return model

# %%
# Binary classification
nn = make_model(logits=False, last_nodes=1)
nn.compile(loss=tf.keras.losses.BinaryCrossentropy, optimizer='adam', metrics=METRICS)
history = nn.fit(X_train_transform, y_train, epochs=30, batch_size=256, validation_data=(X_val_transform, y_val))
# Out:
# Epoch 1/30
# 1414/1414 [==============================] - 16s 10ms/step - loss: 0.6053 - accuracy: 0.6865 - precision: 0.6780 - recall: 0.7105 - auc: 0.7478 - prc: 0.7160 - val_loss: 0.5406 - val_accuracy: 0.7090 - val_precision: 0.1558 - val_recall: 0.5755 - val_auc: 0.7013 - val_prc: 0.1786
# Epoch 2/30
# 1414/1414 [==============================] - 13s 9ms/step - loss: 0.5331 - accuracy: 0.7387 - precision: 0.7292 - recall: 0.7594 - auc: 0.8100 - prc: 0.7896 - val_loss: 0.4925 - val_accuracy: 0.7569 - val_precision: 0.1659 - val_recall: 0.4861 - val_auc: 0.6975 - val_prc: 0.1682
# Epoch 3/30
# 1414/1414 [==============================] - 13s 9ms/step - loss: 0.5078 - accuracy: 0.7566 - precision: 0.7497 - recall: 0.7702 - auc: 0.8311 - prc: 0.8144 - val_loss: 0.4969 - val_accuracy: 0.7481 - val_precision: 0.1621 - val_recall: 0.4955 - val_auc: 0.6922 - val_prc: 0.1669
# Epoch 4/30
# 1414/1414 [==============================] - 13s 9ms/step - loss: 0.4899 - accuracy: 0.7683 - precision: 0.7623 - recall: 0.7797 - auc: 0.8443 - prc: 0.8302 - val_loss: 0.4710 - val_accuracy: 0.7714 - val_precision: 0.1681 - val_recall: 0.4515 - val_auc: 0.6942 - val_prc: 0.1631
# Epoch 5/30
# 1414/1414 [==============================] - 13s 9ms/step - loss: 0.4748 - accuracy: 0.7765 - precision: 0.7707 - recall: 0.7872 - auc: 0.8549 - prc: 0.8417 - val_loss: 0.4590 - val_accuracy: 0.7857 - val_precision: 0.1694 - val_recall: 0.4122 - val_auc: 0.6892 - val_prc: 0.1606
# Epoch 6/30
# 1414/1414 [==============================] - 13s 9ms/step - loss: 0.4608 - accuracy: 0.7861 - precision: 0.7808 - recall: 0.7956 - auc: 0.8643 - prc: 0.8538 - val_loss: 0.4392 - val_accuracy: 0.7918 - val_precision: 0.1772 - val_recall: 0.4213 - val_auc: 0.6991 - val_prc: 0.1701
# Epoch 7/30
# 1414/1414 [==============================] - 13s 9ms/step - loss: 0.4476 - accuracy: 0.7927 - precision: 0.7856 - recall: 0.8051 - auc: 0.8728 - prc: 0.8653 - val_loss: 0.4339 - val_accuracy: 0.7911 - val_precision: 0.1699 - val_recall: 0.3971 - val_auc: 0.6904 - val_prc: 0.1596
# Epoch 8/30
# 1414/1414 [==============================] - 13s 9ms/step - loss: 0.4370 - accuracy: 0.7986 - precision: 0.7895 - recall: 0.8143 - auc: 0.8793 - prc: 0.8740 - val_loss: 0.4255 - val_accuracy: 0.7964 - val_precision: 0.1746 - val_recall: 0.3966 - val_auc: 0.6936 - val_prc: 0.1650
# Epoch 9/30
# 1414/1414 [==============================] - 13s 9ms/step - loss: 0.4286 - accuracy: 0.8035 - precision: 0.7951 - recall: 0.8176 - auc: 0.8842 - prc: 0.8800 - val_loss: 0.4276 - val_accuracy: 0.7920 - val_precision: 0.1704 - val_recall: 0.3961 - val_auc: 0.6861 - val_prc: 0.1589
# Epoch 10/30
# 1414/1414 [==============================] - 13s 9ms/step - loss: 0.4211 - accuracy: 0.8070 - precision: 0.7992 - recall: 0.8199 - auc: 0.8884 - prc: 0.8859 - val_loss: 0.3999 - val_accuracy: 0.8129 - val_precision: 0.1743 - val_recall: 0.3419 - val_auc: 0.6873 - val_prc: 0.1604
# Epoch 11/30
# 1414/1414 [==============================] - 13s 9ms/step - loss: 0.4149 - accuracy: 0.8109 - precision: 0.8019 - recall: 0.8259 - auc: 0.8919 - prc: 0.8895 - val_loss: 0.4158 - val_accuracy: 0.8042 - val_precision: 0.1772 - val_recall: 0.3800 - val_auc: 0.6950 - val_prc: 0.1671
# Epoch 12/30
# 1414/1414 [==============================] - 13s 9ms/step - loss: 0.4085 - accuracy: 0.8142 - precision: 0.8068 - recall: 0.8262 - auc: 0.8954 - prc: 0.8939 - val_loss: 0.4093 - val_accuracy: 0.8124 - val_precision: 0.1814 - val_recall: 0.3652 - val_auc: 0.6928 - val_prc: 0.1660
# Epoch 13/30
# 1414/1414 [==============================] - 13s 9ms/step - loss: 0.4021 - accuracy: 0.8177 - precision: 0.8104 - recall: 0.8294 - auc: 0.8989 - prc: 0.8977 - val_loss: 0.3843 - val_accuracy: 0.8277 - val_precision: 0.1819 - val_recall: 0.3140 - val_auc: 0.6887 - val_prc: 0.1604
# Epoch 14/30
# 1414/1414 [==============================] - 13s 9ms/step - loss: 0.3969 - accuracy: 0.8203 - precision: 0.8138 - recall: 0.8306 - auc: 0.9015 - prc: 0.9010 - val_loss: 0.4093 - val_accuracy: 0.8111 - val_precision: 0.1828 - val_recall: 0.3743 - val_auc: 0.6978 - val_prc: 0.1683
# Epoch 15/30
# 1414/1414 [==============================] - 13s 9ms/step - loss: 0.3934 - accuracy: 0.8220 - precision: 0.8164 - recall: 0.8307 - auc: 0.9033 - prc: 0.9032 - val_loss: 0.4036 - val_accuracy: 0.8141 - val_precision: 0.1786 - val_recall: 0.3508 - val_auc: 0.6924 - val_prc: 0.1597
# Epoch 16/30
# 1414/1414 [==============================] - 13s 9ms/step - loss: 0.3877 - accuracy: 0.8253 - precision: 0.8201 - recall: 0.8334 - auc: 0.9062 - prc: 0.9063 - val_loss: 0.3951 - val_accuracy: 0.8219 - val_precision: 0.1842 - val_recall: 0.3407 - val_auc: 0.6921 - val_prc: 0.1637
# Epoch 17/30
# 1414/1414 [==============================] - 13s 9ms/step - loss: 0.3836 - accuracy: 0.8277 - precision: 0.8225 - recall: 0.8357 - auc: 0.9083 - prc: 0.9084 - val_loss: 0.4026 - val_accuracy: 0.8159 - val_precision: 0.1758 - val_recall: 0.3365 - val_auc: 0.6884 - val_prc: 0.1596
# Epoch 18/30
# 1414/1414 [==============================] - 14s 10ms/step - loss: 0.3816 - accuracy: 0.8285 - precision: 0.8229 - recall: 0.8372 - auc: 0.9093 - prc: 0.9096 - val_loss: 0.3775 - val_accuracy: 0.8331 - val_precision: 0.1850 - val_recall: 0.3028 - val_auc: 0.6919 - val_prc: 0.1619
# Epoch 19/30
# 1414/1414 [==============================] - 14s 10ms/step - loss: 0.3769 - accuracy: 0.8312 - precision: 0.8259 - recall: 0.8392 - auc: 0.9116 - prc: 0.9116 - val_loss: 0.3984 - val_accuracy: 0.8191 - val_precision: 0.1802 - val_recall: 0.3387 - val_auc: 0.6893 - val_prc: 0.1597
# Epoch 20/30
# 1414/1414 [==============================] - 14s 10ms/step - loss: 0.3750 - accuracy: 0.8325 - precision: 0.8285 - recall: 0.8386 - auc: 0.9125 - prc: 0.9133 - val_loss: 0.3815 - val_accuracy: 0.8330 - val_precision: 0.1866 - val_recall: 0.3078 - val_auc: 0.6935 - val_prc: 0.1646
# Epoch 21/30
# 1414/1414 [==============================] - 14s 10ms/step - loss: 0.3713 - accuracy: 0.8341 - precision: 0.8290 - recall: 0.8418 - auc: 0.9144 - prc: 0.9147 - val_loss: 0.3888 - val_accuracy: 0.8262 - val_precision: 0.1829 - val_recall: 0.3216 - val_auc: 0.6886 - val_prc: 0.1598
# Epoch 22/30
# 1414/1414 [==============================] - 14s 10ms/step - loss: 0.3691 - accuracy: 0.8348 - precision: 0.8303 - recall: 0.8417 - auc: 0.9154 - prc: 0.9160 - val_loss: 0.3851 - val_accuracy: 0.8287 - val_precision: 0.1837 - val_recall: 0.3152 - val_auc: 0.6896 - val_prc: 0.1607
# Epoch 23/30
# 1414/1414 [==============================] - 13s 9ms/step - loss: 0.3662 - accuracy: 0.8366 - precision: 0.8319 - recall: 0.8437 - auc: 0.9167 - prc: 0.9174 - val_loss: 0.3850 - val_accuracy: 0.8305 - val_precision: 0.1853 - val_recall: 0.3132 - val_auc: 0.6921 - val_prc: 0.1620
# Epoch 24/30
# 1414/1414 [==============================] - 13s 9ms/step - loss: 0.3635 - accuracy: 0.8382 - precision: 0.8339 - recall: 0.8446 - auc: 0.9180 - prc: 0.9188 - val_loss: 0.3802 - val_accuracy: 0.8326 - val_precision: 0.1881 - val_recall: 0.3127 - val_auc: 0.6920 - val_prc: 0.1630
# Epoch 25/30
# 1414/1414 [==============================] - 13s 9ms/step - loss: 0.3616 - accuracy: 0.8389 - precision: 0.8345 - recall: 0.8455 - auc: 0.9190 - prc: 0.9198 - val_loss: 0.3866 - val_accuracy: 0.8273 - val_precision: 0.1776 - val_recall: 0.3036 - val_auc: 0.6847 - val_prc: 0.1577
# Epoch 26/30
# 1414/1414 [==============================] - 13s 9ms/step - loss: 0.3600 - accuracy: 0.8402 - precision: 0.8363 - recall: 0.8459 - auc: 0.9197 - prc: 0.9204 - val_loss: 0.3732 - val_accuracy: 0.8385 - val_precision: 0.1901 - val_recall: 0.2964 - val_auc: 0.6893 - val_prc: 0.1608
# Epoch 27/30
# 1414/1414 [==============================] - 13s 9ms/step - loss: 0.3571 - accuracy: 0.8418 - precision: 0.8382 - recall: 0.8472 - auc: 0.9211 - prc: 0.9218 - val_loss: 0.3910 - val_accuracy: 0.8255 - val_precision: 0.1869 - val_recall: 0.3355 - val_auc: 0.6933 - val_prc: 0.1637
# Epoch 28/30
# 1414/1414 [==============================] - 13s 9ms/step - loss: 0.3558 - accuracy: 0.8418 - precision: 0.8386 - recall: 0.8466 - auc: 0.9216 - prc: 0.9224 - val_loss: 0.3776 - val_accuracy: 0.8357 - val_precision: 0.1892 - val_recall: 0.3043 - val_auc: 0.6934 - val_prc: 0.1646
# Epoch 29/30
# 1414/1414 [==============================] - 13s 9ms/step - loss: 0.3534 - accuracy: 0.8432 - precision: 0.8388 - recall: 0.8496 - auc: 0.9228 - prc: 0.9231 - val_loss: 0.3691 - val_accuracy: 0.8431 - val_precision: 0.1880 - val_recall: 0.2741 - val_auc: 0.6900 - val_prc: 0.1566
# Epoch 30/30
# 1414/1414 [==============================] - 13s 9ms/step - loss: 0.3511 - accuracy: 0.8440 - precision: 0.8399 - recall: 0.8501 - auc: 0.9238 - prc: 0.9246 - val_loss: 0.3860 - val_accuracy: 0.8296 - val_precision: 0.1861 - val_recall: 0.3184 - val_auc: 0.6932 - val_prc: 0.1613

# %%
scores = nn.evaluate(X_test_transform, y_test)
print("\n%s: %.2f%%" % (nn.metrics_names[1], scores[1]*100))
# Out:
# 1922/1922 [==============================] - 7s 4ms/step - loss: 0.3795 - accuracy: 0.8309 - precision: 0.1879 - recall: 0.3318 - auc: 0.7030 - prc: 0.1651
#
# accuracy: 83.09%

# %%
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('AUC curve')
plt.ylabel('AUC')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss curve')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

def plot_prc(name, labels, predictions, **kwargs):
    precision, recall, _ = sklearn.metrics.precision_recall_curve(labels, predictions)

    plt.plot(precision, recall, label=name, linewidth=2, **kwargs)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.grid(True)
    ax = plt.gca()
    ax.set_aspect('equal')

from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=80)
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
train_predictions_resampled = nn.predict(X_train, batch_size=128)
test_predictions_resampled =  nn.predict(X_test, batch_size=128)
plot_prc("Train Resampled", y_train, train_predictions_resampled, color=colors[2])
plot_prc("Test Resampled", y_test, test_predictions_resampled, color=colors[2], linestyle='--')
plt.legend(loc='lower right')



# results = model.evaluate(X_test, y_test, batch_size=64)

# %%
y_pred = nn.predict(X_test_transform)
confusion_matrix = sklearn.metrics.confusion_matrix(y_test, np.rint(y_pred))

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix, display_labels=["0","1"])

# %%
disp.plot()

# %% [markdown]
# # Membership Inference Attack

# %% [markdown]
# Membership Inference Attack (MIA) on machine learning models aim to identify whether a data sample was used to train the target machine learning model or not.
#
# MIA can raise severe privacy risks to individuals. For example, identifying that a certain patient’s clinical record was used to train a model associated with a disease reveals that the patient has this disease.
# MIA against ML models mainly focus on deep learning models because they are more prone to suffer from overfitting issues, which can be exploited by membership inference attacks
#
# If our model behaves differently on both train and test datasets, it may be the case that the model overfits on the train data therefore is more vulnerable to MIA.
#
# There are two types of MIA Attacks:
# * Neural Network based attacks
# * Metrics based attacks
#
#
# Types of Membership Inference Attacks:
# * Black-box inference attacks
# * White-box inference attacks
#
# Steps to mitigate MIA:
#
# * Regularization to prevent overfitting.
#
# * Using Differential Privacy as privacy enhancing technique
#
# * Confidence score masking
#
# Generalized steps to explore MIA:
#
# * Load dataset & preprocess.
# * Create the model without activation in the last layer and logits set to True in the loss function and train.
# * Perform attack on the model and keep note of the relevant success metric (AUC used in this notebook).
# * Implement differential privacy to see difference in the success metric (AUC used in this notebook).

# %%
from tensorflow_privacy.privacy.membership_inference_attack import membership_inference_attack as mia
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import AttackInputData
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import SlicingSpec
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import AttackType
import tensorflow_privacy.privacy.membership_inference_attack.plotting as plotting

import tensorflow_privacy.privacy.privacy_tests.membership_inference_attack
from scipy import special

# %% [markdown]
# Imports for the Membership Inference Attack (MIA) , we proceed to import datastructures that will help with MIA.
#
# `AttackInputData` is used to specify what information *f*<sub>*attack*</sub> will recieve. *f*<sub>*attack*</sub> is the binary classifier used to predict whether a data point was part of the training data or not. The *f*<sub>*attack*</sub>  is the binary classifier trained to predict, whether this data point was part of the training data or not. The input for the training the *f*<sub>*attack*</sub> are outputs (or other whitebox-like information) of a trained shadow models and the binary target is based on the dact that data has beeb used for training the associated shadow model.
#
# We can provide these parameters for the `AttackInputData`:
#
# * `train and test logits or train and test probabilities`
# * `train and test loss`
# * `train and test labels (as integer arrays)`
#
# `SlicingSpec`: Provide us with the possibility of slicing our dataset. Using this datastructure, we can determine the success of the membership inference attack over specific data groups or classes. The following options can be set to True:
#
# * `entire_dataset: one of the slices will be the entire dataset`
# * `by_class: one slice per class is generated`
# * `by_percentiles: generates 10 slices for percentiles of the loss - 0-10% 10-20%, … 90-100%`
# * `by_classification_correctness: creates one slice for correctly classified data points, and one for misclassified data points. `
#
# `AttackType`: Gives us different options on how our membership inference attack should be conducted. We can specify the model that we would like to use:
#
# * `LOGISTIC_REGRESSION = ‘lr’`
# * `MULTI_LAYERED_PERCEPTRON = ‘mlp’`
# * `RANDOM_FOREST = ‘rf’`
# * `K_NEAREST_NEIGHBORS = ‘knn’`
# * `THRESHOLD_ATTACK = ‘threshold’`
# * `THRESHOLD_ENTROPY_ATTACK = ‘threshold-entropy’`
#
# The four first options require training a shadow model, the two last options don’t.

# %% [markdown]
# # Base Line Model with Logits Output

# %%
nn2 = make_model(logits=True, last_nodes=2)
nn2.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), optimizer='adam', metrics=['accuracy'])
# nn2 = Sequential()
# nn2.add(Dense(units = params['layer1'] , input_dim = X_train.shape[-1]))
# nn2.add(PReLU())
# nn2.add(Dropout(params['dropout']))
# nn2.add(Dense(units = params['layer2'] ))
# nn2.add(PReLU())
# nn2.add(BatchNormalization())
# nn2.add(Dropout(params['dropout']))
# nn2.add(Dense(units = params['layer3']))
# nn2.add(PReLU())
# nn2.add(BatchNormalization())
# nn2.add(Dropout(params['dropout']))
# nn2.add(Dense(units = params['layer4']))
# nn2.add(PReLU())
# nn2.add(BatchNormalization())
# nn2.add(Dropout(params['dropout']))
# nn2.add(Dense(units = params['layer5'], activation="relu"))
# nn2.add(PReLU())
# nn2.add(BatchNormalization())
# nn2.add(Dropout(params['dropout']))
# nn2.add(Dense(2))
# nn2.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), optimizer='adam', metrics=['accuracy'])

# %%
history = nn2.fit(X_train_transform, y_train, epochs=100, batch_size=256, validation_data=(X_val_transform, y_val))
# Out:
# Epoch 1/100
# 1414/1414 [==============================] - 12s 7ms/step - loss: 0.5921 - accuracy: 0.6932 - val_loss: 0.5005 - val_accuracy: 0.7457
# Epoch 2/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.5302 - accuracy: 0.7411 - val_loss: 0.4915 - val_accuracy: 0.7596
# Epoch 3/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.5071 - accuracy: 0.7561 - val_loss: 0.4879 - val_accuracy: 0.7632
# Epoch 4/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.4904 - accuracy: 0.7684 - val_loss: 0.4491 - val_accuracy: 0.7974
# Epoch 5/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.4764 - accuracy: 0.7761 - val_loss: 0.4725 - val_accuracy: 0.7726
# Epoch 6/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.4632 - accuracy: 0.7837 - val_loss: 0.4581 - val_accuracy: 0.7852
# Epoch 7/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.4525 - accuracy: 0.7905 - val_loss: 0.4761 - val_accuracy: 0.7603
# Epoch 8/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.4431 - accuracy: 0.7961 - val_loss: 0.4305 - val_accuracy: 0.7933
# Epoch 9/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.4338 - accuracy: 0.8012 - val_loss: 0.4322 - val_accuracy: 0.7944
# Epoch 10/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.4247 - accuracy: 0.8066 - val_loss: 0.4307 - val_accuracy: 0.7944
# Epoch 11/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.4180 - accuracy: 0.8089 - val_loss: 0.4236 - val_accuracy: 0.8001
# Epoch 12/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.4111 - accuracy: 0.8136 - val_loss: 0.4219 - val_accuracy: 0.7987
# Epoch 13/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.4047 - accuracy: 0.8167 - val_loss: 0.4105 - val_accuracy: 0.8043
# Epoch 14/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3998 - accuracy: 0.8192 - val_loss: 0.4182 - val_accuracy: 0.8021
# Epoch 15/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3941 - accuracy: 0.8217 - val_loss: 0.4038 - val_accuracy: 0.8161
# Epoch 16/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3906 - accuracy: 0.8245 - val_loss: 0.4141 - val_accuracy: 0.8048
# Epoch 17/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3861 - accuracy: 0.8267 - val_loss: 0.4038 - val_accuracy: 0.8136
# Epoch 18/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3828 - accuracy: 0.8280 - val_loss: 0.3943 - val_accuracy: 0.8178
# Epoch 19/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3787 - accuracy: 0.8297 - val_loss: 0.3843 - val_accuracy: 0.8270
# Epoch 20/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3751 - accuracy: 0.8318 - val_loss: 0.3939 - val_accuracy: 0.8193
# Epoch 21/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3716 - accuracy: 0.8336 - val_loss: 0.4063 - val_accuracy: 0.8120
# Epoch 22/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3684 - accuracy: 0.8345 - val_loss: 0.3914 - val_accuracy: 0.8262
# Epoch 23/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3659 - accuracy: 0.8369 - val_loss: 0.3756 - val_accuracy: 0.8354
# Epoch 24/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3637 - accuracy: 0.8380 - val_loss: 0.3798 - val_accuracy: 0.8321
# Epoch 25/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3621 - accuracy: 0.8388 - val_loss: 0.3947 - val_accuracy: 0.8248
# Epoch 26/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3593 - accuracy: 0.8400 - val_loss: 0.3791 - val_accuracy: 0.8343
# Epoch 27/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3567 - accuracy: 0.8418 - val_loss: 0.3746 - val_accuracy: 0.8384
# Epoch 28/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3546 - accuracy: 0.8426 - val_loss: 0.3867 - val_accuracy: 0.8269
# Epoch 29/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3540 - accuracy: 0.8435 - val_loss: 0.3650 - val_accuracy: 0.8420
# Epoch 30/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3518 - accuracy: 0.8442 - val_loss: 0.3814 - val_accuracy: 0.8324
# Epoch 31/100
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3495 - accuracy: 0.8453 - val_loss: 0.3876 - val_accuracy: 0.8256
# Epoch 32/100
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3470 - accuracy: 0.8472 - val_loss: 0.3677 - val_accuracy: 0.8382
# Epoch 33/100
# 1414/1414 [==============================] - 11s 7ms/step - loss: 0.3454 - accuracy: 0.8470 - val_loss: 0.3708 - val_accuracy: 0.8399
# Epoch 34/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3446 - accuracy: 0.8481 - val_loss: 0.3875 - val_accuracy: 0.8291
# Epoch 35/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3424 - accuracy: 0.8487 - val_loss: 0.3762 - val_accuracy: 0.8351
# Epoch 36/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3427 - accuracy: 0.8490 - val_loss: 0.3923 - val_accuracy: 0.8243
# Epoch 37/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3406 - accuracy: 0.8499 - val_loss: 0.3695 - val_accuracy: 0.8413
# Epoch 38/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3388 - accuracy: 0.8503 - val_loss: 0.3871 - val_accuracy: 0.8288
# Epoch 39/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3385 - accuracy: 0.8510 - val_loss: 0.3821 - val_accuracy: 0.8327
# Epoch 40/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3372 - accuracy: 0.8519 - val_loss: 0.3762 - val_accuracy: 0.8360
# Epoch 41/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3356 - accuracy: 0.8528 - val_loss: 0.3743 - val_accuracy: 0.8407
# Epoch 42/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3352 - accuracy: 0.8529 - val_loss: 0.3685 - val_accuracy: 0.8433
# Epoch 43/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3343 - accuracy: 0.8535 - val_loss: 0.3567 - val_accuracy: 0.8541
# Epoch 44/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3326 - accuracy: 0.8540 - val_loss: 0.3767 - val_accuracy: 0.8384
# Epoch 45/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3314 - accuracy: 0.8552 - val_loss: 0.3741 - val_accuracy: 0.8390
# Epoch 46/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3302 - accuracy: 0.8554 - val_loss: 0.3707 - val_accuracy: 0.8416
# Epoch 47/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3299 - accuracy: 0.8559 - val_loss: 0.3568 - val_accuracy: 0.8520
# Epoch 48/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3281 - accuracy: 0.8558 - val_loss: 0.3701 - val_accuracy: 0.8435
# Epoch 49/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3281 - accuracy: 0.8560 - val_loss: 0.3687 - val_accuracy: 0.8422
# Epoch 50/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3271 - accuracy: 0.8574 - val_loss: 0.3747 - val_accuracy: 0.8411
# Epoch 51/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3255 - accuracy: 0.8586 - val_loss: 0.3650 - val_accuracy: 0.8436
# Epoch 52/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3254 - accuracy: 0.8579 - val_loss: 0.3738 - val_accuracy: 0.8399
# Epoch 53/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3234 - accuracy: 0.8588 - val_loss: 0.3706 - val_accuracy: 0.8437
# Epoch 54/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3231 - accuracy: 0.8592 - val_loss: 0.3602 - val_accuracy: 0.8500
# Epoch 55/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3230 - accuracy: 0.8598 - val_loss: 0.3838 - val_accuracy: 0.8338
# Epoch 56/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3219 - accuracy: 0.8600 - val_loss: 0.3706 - val_accuracy: 0.8458
# Epoch 57/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3221 - accuracy: 0.8600 - val_loss: 0.3594 - val_accuracy: 0.8509
# Epoch 58/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3209 - accuracy: 0.8609 - val_loss: 0.3737 - val_accuracy: 0.8424
# Epoch 59/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3204 - accuracy: 0.8607 - val_loss: 0.3606 - val_accuracy: 0.8491
# Epoch 60/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3179 - accuracy: 0.8619 - val_loss: 0.3698 - val_accuracy: 0.8426
# Epoch 61/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3185 - accuracy: 0.8620 - val_loss: 0.3706 - val_accuracy: 0.8431
# Epoch 62/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3179 - accuracy: 0.8618 - val_loss: 0.3673 - val_accuracy: 0.8467
# Epoch 63/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3171 - accuracy: 0.8626 - val_loss: 0.3684 - val_accuracy: 0.8483
# Epoch 64/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3172 - accuracy: 0.8627 - val_loss: 0.3800 - val_accuracy: 0.8361
# Epoch 65/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3158 - accuracy: 0.8637 - val_loss: 0.3658 - val_accuracy: 0.8472
# Epoch 66/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3150 - accuracy: 0.8635 - val_loss: 0.3607 - val_accuracy: 0.8520
# Epoch 67/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3143 - accuracy: 0.8635 - val_loss: 0.3591 - val_accuracy: 0.8557
# Epoch 68/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3131 - accuracy: 0.8648 - val_loss: 0.3744 - val_accuracy: 0.8473
# Epoch 69/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3145 - accuracy: 0.8643 - val_loss: 0.3796 - val_accuracy: 0.8403
# Epoch 70/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3124 - accuracy: 0.8650 - val_loss: 0.3783 - val_accuracy: 0.8403
# Epoch 71/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3127 - accuracy: 0.8646 - val_loss: 0.3613 - val_accuracy: 0.8575
# Epoch 72/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3121 - accuracy: 0.8651 - val_loss: 0.3702 - val_accuracy: 0.8452
# Epoch 73/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3108 - accuracy: 0.8661 - val_loss: 0.3589 - val_accuracy: 0.8538
# Epoch 74/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3106 - accuracy: 0.8664 - val_loss: 0.3799 - val_accuracy: 0.8373
# Epoch 75/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3113 - accuracy: 0.8662 - val_loss: 0.3804 - val_accuracy: 0.8370
# Epoch 76/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3099 - accuracy: 0.8663 - val_loss: 0.3566 - val_accuracy: 0.8561
# Epoch 77/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3088 - accuracy: 0.8671 - val_loss: 0.3662 - val_accuracy: 0.8466
# Epoch 78/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3090 - accuracy: 0.8667 - val_loss: 0.3701 - val_accuracy: 0.8456
# Epoch 79/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3074 - accuracy: 0.8672 - val_loss: 0.3485 - val_accuracy: 0.8589
# Epoch 80/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3075 - accuracy: 0.8670 - val_loss: 0.3705 - val_accuracy: 0.8461
# Epoch 81/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3075 - accuracy: 0.8677 - val_loss: 0.3602 - val_accuracy: 0.8535
# Epoch 82/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3057 - accuracy: 0.8684 - val_loss: 0.3799 - val_accuracy: 0.8424
# Epoch 83/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3057 - accuracy: 0.8686 - val_loss: 0.3718 - val_accuracy: 0.8501
# Epoch 84/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3063 - accuracy: 0.8681 - val_loss: 0.3716 - val_accuracy: 0.8473
# Epoch 85/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3054 - accuracy: 0.8688 - val_loss: 0.3594 - val_accuracy: 0.8561
# Epoch 86/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3051 - accuracy: 0.8691 - val_loss: 0.3570 - val_accuracy: 0.8559
# Epoch 87/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3040 - accuracy: 0.8692 - val_loss: 0.3767 - val_accuracy: 0.8452
# Epoch 88/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3035 - accuracy: 0.8698 - val_loss: 0.3488 - val_accuracy: 0.8595
# Epoch 89/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3043 - accuracy: 0.8692 - val_loss: 0.3567 - val_accuracy: 0.8573
# Epoch 90/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3022 - accuracy: 0.8706 - val_loss: 0.3638 - val_accuracy: 0.8547
# Epoch 91/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3022 - accuracy: 0.8700 - val_loss: 0.3649 - val_accuracy: 0.8505
# Epoch 92/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3014 - accuracy: 0.8707 - val_loss: 0.3541 - val_accuracy: 0.8614
# Epoch 93/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3024 - accuracy: 0.8703 - val_loss: 0.3587 - val_accuracy: 0.8546
# Epoch 94/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3002 - accuracy: 0.8712 - val_loss: 0.3529 - val_accuracy: 0.8617
# Epoch 95/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3018 - accuracy: 0.8706 - val_loss: 0.3603 - val_accuracy: 0.8535
# Epoch 96/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.3000 - accuracy: 0.8717 - val_loss: 0.3734 - val_accuracy: 0.8442
# Epoch 97/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.2996 - accuracy: 0.8713 - val_loss: 0.3606 - val_accuracy: 0.8541
# Epoch 98/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.2997 - accuracy: 0.8714 - val_loss: 0.3673 - val_accuracy: 0.8477
# Epoch 99/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.2994 - accuracy: 0.8716 - val_loss: 0.3625 - val_accuracy: 0.8518
# Epoch 100/100
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.2997 - accuracy: 0.8715 - val_loss: 0.3623 - val_accuracy: 0.8507

# %% [markdown]
# ### Before conducting the attack we need to calculate the inputs the attacker needs. Here we calculate the output logits, output probabilities and losses for train-test split

# %%
print('Predict on train...')
logits_train = nn2.predict(X_train_transform)

print('Predict on test...')
logits_test = nn2.predict(X_test_transform)

print('Apply softmax to get probabilities from logits...')
prob_train = special.softmax(logits_train, axis=1)
prob_test = special.softmax(logits_test, axis=1)

print('Compute losses...')
cce = tf.keras.backend.categorical_crossentropy
constant = tf.keras.backend.constant

y_train_1 = np.array(y_train, dtype=np.float32) 
y_test_1 = np.array(y_test, dtype=np.float32) 

y_train_1 = y_train_1.flatten()
y_test_1 = y_test_1.flatten()

y_train_onehot_1 = to_categorical(y_train_1)
y_test_onehot_1 = to_categorical(y_test_1)


loss_train = cce(constant(y_train_onehot_1), constant(prob_train), from_logits=False).numpy()
loss_test = cce(constant(y_test_onehot_1), constant(prob_test), from_logits=False).numpy()
# Out:
# Predict on train...
# Predict on test...
# Apply softmax to get probabilities from logits...
# Compute losses...

# %% [markdown]
# ### We define what variables our attacker has access too

# %%
attack_input = AttackInputData(
  logits_train = logits_train,
  logits_test = logits_test,
  loss_train = loss_train,
  loss_test = loss_test,
  labels_train = y_train_1.astype(np.int8),
  labels_test = y_test_1.astype(np.int8)
)

# %% [markdown]
# ### We specify data partitions that we would like to run attacks on

# %%
slicing_spec = SlicingSpec(
    entire_dataset = True,
    by_class = True,
    by_percentiles = False,
    by_classification_correctness = True)

# %% [markdown]
# ### Finally we define our attack types and run our attack

# %%
attack_types = [
    AttackType.THRESHOLD_ATTACK,
    AttackType.LOGISTIC_REGRESSION
]
# run the attack
attacks_result = mia.run_attacks(attack_input=attack_input,
                                 slicing_spec=slicing_spec,
                                 attack_types=attack_types)

# %%
print(attacks_result.summary(by_slices=True))
# Out:
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 4949 training and 4949 test examples) achieved an AUC of 0.93 on slice CLASS=1
#   LOGISTIC_REGRESSION (with 4949 training and 4949 test examples) achieved an advantage of 0.70 on slice CLASS=1
#
# Best-performing attacks over slice: "Entire dataset"
#   LOGISTIC_REGRESSION (with 61503 training and 61503 test examples) achieved an AUC of 0.72
#   LOGISTIC_REGRESSION (with 61503 training and 61503 test examples) achieved an advantage of 0.43
#
# Best-performing attacks over slice: "CLASS=0"
#   THRESHOLD_ATTACK (with 180972 training and 56554 test examples) achieved an AUC of 0.52
#   THRESHOLD_ATTACK (with 180972 training and 56554 test examples) achieved an advantage of 0.03
#
# Best-performing attacks over slice: "CLASS=1"
#   LOGISTIC_REGRESSION (with 4949 training and 4949 test examples) achieved an AUC of 0.93
#   LOGISTIC_REGRESSION (with 4949 training and 4949 test examples) achieved an advantage of 0.70
#
# Best-performing attacks over slice: "CORRECTLY_CLASSIFIED=True"
#   LOGISTIC_REGRESSION (with 52395 training and 52395 test examples) achieved an AUC of 0.74
#   LOGISTIC_REGRESSION (with 52395 training and 52395 test examples) achieved an advantage of 0.47
#
# Best-performing attacks over slice: "CORRECTLY_CLASSIFIED=False"
#   LOGISTIC_REGRESSION (with 9108 training and 9108 test examples) achieved an AUC of 0.66
#   LOGISTIC_REGRESSION (with 9108 training and 9108 test examples) achieved an advantage of 0.24

# %%
# We see that the attacker is much better than random accuracy
print(plotting.plot_roc_curve(attacks_result.get_result_with_max_auc().roc_curve))
# Out:
# Figure(432x288)

# %% [markdown]
# ### Running Same Experiment with differential privacy

# %%
from tensorflow_privacy.privacy.optimizers.dp_optimizer_keras import DPKerasAdamOptimizer

# %% [markdown]
# ### Baseline Model with Logits output and DP optimizer

# %%
noise_multiplier=.01
l2_norm_clip=1
num_microbatches=1

dp = DPKerasAdamOptimizer(
            l2_norm_clip=l2_norm_clip,
            noise_multiplier=noise_multiplier,num_microbatches=num_microbatches)

nn3 = Sequential()
nn3.add(Dense(units = params['layer1'] , input_dim = X_train.shape[-1]))
nn3.add(PReLU())
nn3.add(Dropout(params['dropout']))
nn3.add(Dense(units = params['layer2'] ))
nn3.add(PReLU())
nn3.add(BatchNormalization())
nn3.add(Dropout(params['dropout']))
nn3.add(Dense(units = params['layer3']))
nn3.add(PReLU())
nn3.add(BatchNormalization())
nn3.add(Dropout(params['dropout']))
nn3.add(Dense(units = params['layer4']))
nn3.add(PReLU())
nn3.add(BatchNormalization())
nn3.add(Dropout(params['dropout']))
nn3.add(Dense(units = params['layer5'], activation="relu"))
nn3.add(PReLU())
nn3.add(BatchNormalization())
nn3.add(Dropout(params['dropout']))
nn3.add(Dense(2))
nn3.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), optimizer=dp, metrics=['accuracy'])

# %%
history = nn3.fit(X_train_transform, y_train, epochs=100, batch_size=256, validation_data=(X_val_transform, y_val))
# Out:
# Epoch 1/100
# 1414/1414 [==============================] - 26s 13ms/step - loss: 0.6294 - accuracy: 0.6636 - val_loss: 0.6180 - val_accuracy: 0.6370
# Epoch 2/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5763 - accuracy: 0.7048 - val_loss: 0.6220 - val_accuracy: 0.6383
# Epoch 3/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5650 - accuracy: 0.7155 - val_loss: 0.6124 - val_accuracy: 0.6462
# Epoch 4/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5574 - accuracy: 0.7205 - val_loss: 0.6212 - val_accuracy: 0.6468
# Epoch 5/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5538 - accuracy: 0.7236 - val_loss: 0.6209 - val_accuracy: 0.6529
# Epoch 6/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5503 - accuracy: 0.7265 - val_loss: 0.6248 - val_accuracy: 0.6521
# Epoch 7/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5482 - accuracy: 0.7275 - val_loss: 0.6132 - val_accuracy: 0.6592
# Epoch 8/100
# 1414/1414 [==============================] - 17s 12ms/step - loss: 0.5463 - accuracy: 0.7301 - val_loss: 0.6225 - val_accuracy: 0.6502
# Epoch 9/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5429 - accuracy: 0.7319 - val_loss: 0.6088 - val_accuracy: 0.6626
# Epoch 10/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5418 - accuracy: 0.7328 - val_loss: 0.6098 - val_accuracy: 0.6663
# Epoch 11/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5401 - accuracy: 0.7335 - val_loss: 0.6104 - val_accuracy: 0.6626
# Epoch 12/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5395 - accuracy: 0.7343 - val_loss: 0.6121 - val_accuracy: 0.6621
# Epoch 13/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5373 - accuracy: 0.7359 - val_loss: 0.6093 - val_accuracy: 0.6689
# Epoch 14/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5366 - accuracy: 0.7361 - val_loss: 0.6086 - val_accuracy: 0.6642
# Epoch 15/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5354 - accuracy: 0.7379 - val_loss: 0.6179 - val_accuracy: 0.6658
# Epoch 16/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5347 - accuracy: 0.7381 - val_loss: 0.6174 - val_accuracy: 0.6643
# Epoch 17/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5332 - accuracy: 0.7392 - val_loss: 0.6111 - val_accuracy: 0.6703
# Epoch 18/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5322 - accuracy: 0.7401 - val_loss: 0.6144 - val_accuracy: 0.6668
# Epoch 19/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5312 - accuracy: 0.7409 - val_loss: 0.6036 - val_accuracy: 0.6754
# Epoch 20/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5300 - accuracy: 0.7407 - val_loss: 0.6046 - val_accuracy: 0.6701
# Epoch 21/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5299 - accuracy: 0.7416 - val_loss: 0.5918 - val_accuracy: 0.6806
# Epoch 22/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5289 - accuracy: 0.7427 - val_loss: 0.5952 - val_accuracy: 0.6906
# Epoch 23/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5291 - accuracy: 0.7426 - val_loss: 0.6017 - val_accuracy: 0.6827
# Epoch 24/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5293 - accuracy: 0.7423 - val_loss: 0.5984 - val_accuracy: 0.6937
# Epoch 25/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5281 - accuracy: 0.7425 - val_loss: 0.5984 - val_accuracy: 0.6819
# Epoch 26/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5282 - accuracy: 0.7433 - val_loss: 0.5996 - val_accuracy: 0.6850
# Epoch 27/100
# 1414/1414 [==============================] - 17s 12ms/step - loss: 0.5279 - accuracy: 0.7430 - val_loss: 0.5964 - val_accuracy: 0.6874
# Epoch 28/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5270 - accuracy: 0.7437 - val_loss: 0.6023 - val_accuracy: 0.6808
# Epoch 29/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5267 - accuracy: 0.7437 - val_loss: 0.6052 - val_accuracy: 0.6729
# Epoch 30/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5266 - accuracy: 0.7443 - val_loss: 0.6074 - val_accuracy: 0.6799
# Epoch 31/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5264 - accuracy: 0.7444 - val_loss: 0.5970 - val_accuracy: 0.6877
# Epoch 32/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5259 - accuracy: 0.7450 - val_loss: 0.6099 - val_accuracy: 0.6757
# Epoch 33/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5259 - accuracy: 0.7443 - val_loss: 0.5866 - val_accuracy: 0.6971
# Epoch 34/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5261 - accuracy: 0.7439 - val_loss: 0.6022 - val_accuracy: 0.6799
# Epoch 35/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5260 - accuracy: 0.7444 - val_loss: 0.5992 - val_accuracy: 0.6831
# Epoch 36/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5249 - accuracy: 0.7454 - val_loss: 0.6050 - val_accuracy: 0.6798
# Epoch 37/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5253 - accuracy: 0.7445 - val_loss: 0.5945 - val_accuracy: 0.6850
# Epoch 38/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5250 - accuracy: 0.7447 - val_loss: 0.6000 - val_accuracy: 0.6874
# Epoch 39/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5248 - accuracy: 0.7459 - val_loss: 0.5962 - val_accuracy: 0.6845
# Epoch 40/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5250 - accuracy: 0.7461 - val_loss: 0.6056 - val_accuracy: 0.6840
# Epoch 41/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5240 - accuracy: 0.7456 - val_loss: 0.5903 - val_accuracy: 0.6906
# Epoch 42/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5236 - accuracy: 0.7461 - val_loss: 0.6081 - val_accuracy: 0.6790
# Epoch 43/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5228 - accuracy: 0.7463 - val_loss: 0.5900 - val_accuracy: 0.6908
# Epoch 44/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5226 - accuracy: 0.7468 - val_loss: 0.6048 - val_accuracy: 0.6843
# Epoch 45/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5232 - accuracy: 0.7463 - val_loss: 0.5952 - val_accuracy: 0.6878
# Epoch 46/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5223 - accuracy: 0.7468 - val_loss: 0.5924 - val_accuracy: 0.6913
# Epoch 47/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5228 - accuracy: 0.7471 - val_loss: 0.6013 - val_accuracy: 0.6748
# Epoch 48/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5219 - accuracy: 0.7470 - val_loss: 0.5963 - val_accuracy: 0.6902
# Epoch 49/100
# 1414/1414 [==============================] - 17s 12ms/step - loss: 0.5214 - accuracy: 0.7477 - val_loss: 0.5863 - val_accuracy: 0.6933
# Epoch 50/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5224 - accuracy: 0.7467 - val_loss: 0.5894 - val_accuracy: 0.6864
# Epoch 51/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5221 - accuracy: 0.7475 - val_loss: 0.5960 - val_accuracy: 0.6867
# Epoch 52/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5219 - accuracy: 0.7468 - val_loss: 0.5973 - val_accuracy: 0.6791
# Epoch 53/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5215 - accuracy: 0.7472 - val_loss: 0.5957 - val_accuracy: 0.6828
# Epoch 54/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5216 - accuracy: 0.7479 - val_loss: 0.5980 - val_accuracy: 0.6774
# Epoch 55/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5214 - accuracy: 0.7473 - val_loss: 0.5944 - val_accuracy: 0.6811
# Epoch 56/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5220 - accuracy: 0.7475 - val_loss: 0.6029 - val_accuracy: 0.6776
# Epoch 57/100
# 1414/1414 [==============================] - 18s 13ms/step - loss: 0.5211 - accuracy: 0.7481 - val_loss: 0.6049 - val_accuracy: 0.6789
# Epoch 58/100
# 1414/1414 [==============================] - 18s 13ms/step - loss: 0.5193 - accuracy: 0.7490 - val_loss: 0.5912 - val_accuracy: 0.6887
# Epoch 59/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5200 - accuracy: 0.7485 - val_loss: 0.6029 - val_accuracy: 0.6754
# Epoch 60/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5201 - accuracy: 0.7484 - val_loss: 0.5970 - val_accuracy: 0.6827
# Epoch 61/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5207 - accuracy: 0.7480 - val_loss: 0.5925 - val_accuracy: 0.6884
# Epoch 62/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5200 - accuracy: 0.7487 - val_loss: 0.5987 - val_accuracy: 0.6812
# Epoch 63/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5200 - accuracy: 0.7484 - val_loss: 0.6061 - val_accuracy: 0.6808
# Epoch 64/100
# 1414/1414 [==============================] - 17s 12ms/step - loss: 0.5212 - accuracy: 0.7487 - val_loss: 0.5934 - val_accuracy: 0.6915
# Epoch 65/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5205 - accuracy: 0.7483 - val_loss: 0.5942 - val_accuracy: 0.6865
# Epoch 66/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5196 - accuracy: 0.7489 - val_loss: 0.5922 - val_accuracy: 0.6938
# Epoch 67/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5196 - accuracy: 0.7490 - val_loss: 0.5851 - val_accuracy: 0.6901
# Epoch 68/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5196 - accuracy: 0.7483 - val_loss: 0.5838 - val_accuracy: 0.6899
# Epoch 69/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5189 - accuracy: 0.7491 - val_loss: 0.5848 - val_accuracy: 0.6944
# Epoch 70/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5193 - accuracy: 0.7491 - val_loss: 0.5938 - val_accuracy: 0.6840
# Epoch 71/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5196 - accuracy: 0.7484 - val_loss: 0.5799 - val_accuracy: 0.6978
# Epoch 72/100
# 1414/1414 [==============================] - 17s 12ms/step - loss: 0.5187 - accuracy: 0.7489 - val_loss: 0.5855 - val_accuracy: 0.6896
# Epoch 73/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5194 - accuracy: 0.7480 - val_loss: 0.5745 - val_accuracy: 0.6987
# Epoch 74/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5184 - accuracy: 0.7492 - val_loss: 0.5775 - val_accuracy: 0.6963
# Epoch 75/100
# 1414/1414 [==============================] - 17s 12ms/step - loss: 0.5183 - accuracy: 0.7498 - val_loss: 0.5877 - val_accuracy: 0.6886
# Epoch 76/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5188 - accuracy: 0.7498 - val_loss: 0.5974 - val_accuracy: 0.6855
# Epoch 77/100
# 1414/1414 [==============================] - 17s 12ms/step - loss: 0.5194 - accuracy: 0.7494 - val_loss: 0.5875 - val_accuracy: 0.6952
# Epoch 78/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5180 - accuracy: 0.7503 - val_loss: 0.5854 - val_accuracy: 0.6950
# Epoch 79/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5184 - accuracy: 0.7499 - val_loss: 0.5898 - val_accuracy: 0.6890
# Epoch 80/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5186 - accuracy: 0.7493 - val_loss: 0.5903 - val_accuracy: 0.6844
# Epoch 81/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5184 - accuracy: 0.7496 - val_loss: 0.5936 - val_accuracy: 0.6838
# Epoch 82/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5178 - accuracy: 0.7502 - val_loss: 0.5789 - val_accuracy: 0.6926
# Epoch 83/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5191 - accuracy: 0.7491 - val_loss: 0.5891 - val_accuracy: 0.6855
# Epoch 84/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5177 - accuracy: 0.7504 - val_loss: 0.5927 - val_accuracy: 0.6839
# Epoch 85/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5182 - accuracy: 0.7497 - val_loss: 0.5856 - val_accuracy: 0.6843
# Epoch 86/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5179 - accuracy: 0.7507 - val_loss: 0.5905 - val_accuracy: 0.6891
# Epoch 87/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5176 - accuracy: 0.7506 - val_loss: 0.5791 - val_accuracy: 0.7003
# Epoch 88/100
# 1414/1414 [==============================] - 18s 13ms/step - loss: 0.5180 - accuracy: 0.7503 - val_loss: 0.5908 - val_accuracy: 0.6881
# Epoch 89/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5178 - accuracy: 0.7501 - val_loss: 0.5876 - val_accuracy: 0.6892
# Epoch 90/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5168 - accuracy: 0.7509 - val_loss: 0.6002 - val_accuracy: 0.6790
# Epoch 91/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5178 - accuracy: 0.7503 - val_loss: 0.5888 - val_accuracy: 0.6864
# Epoch 92/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5170 - accuracy: 0.7512 - val_loss: 0.5932 - val_accuracy: 0.6858
# Epoch 93/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5154 - accuracy: 0.7519 - val_loss: 0.5895 - val_accuracy: 0.6875
# Epoch 94/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5163 - accuracy: 0.7513 - val_loss: 0.5815 - val_accuracy: 0.7029
# Epoch 95/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5154 - accuracy: 0.7518 - val_loss: 0.5843 - val_accuracy: 0.6952
# Epoch 96/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5163 - accuracy: 0.7512 - val_loss: 0.5894 - val_accuracy: 0.6874
# Epoch 97/100
# 1414/1414 [==============================] - 18s 13ms/step - loss: 0.5155 - accuracy: 0.7525 - val_loss: 0.5876 - val_accuracy: 0.6935
# Epoch 98/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5164 - accuracy: 0.7518 - val_loss: 0.5863 - val_accuracy: 0.6908
# Epoch 99/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5159 - accuracy: 0.7519 - val_loss: 0.5817 - val_accuracy: 0.6943
# Epoch 100/100
# 1414/1414 [==============================] - 18s 12ms/step - loss: 0.5150 - accuracy: 0.7517 - val_loss: 0.5868 - val_accuracy: 0.6889

# %%
from copy import deepcopy
def membership_inference_attack(model, X_train, X_test, train_label, test_label):
    X_train = deepcopy(X_train)
    X_test = deepcopy(X_test)
    train_label = deepcopy(train_label)
    test_label = deepcopy(test_label)
    
    print('Predict on train...')
    logits_train = model.predict(X_train)

    print('Predict on test...')
    logits_test = model.predict(X_test)

    print('Apply softmax to get probabilities from logits...')
    prob_train = special.softmax(logits_train, axis=1)
    prob_test = special.softmax(logits_test, axis=1)

    print('Compute losses...')
    cce = tf.keras.backend.categorical_crossentropy
    constant = tf.keras.backend.constant

    y_train = np.array(train_label, dtype=np.float32) 
    y_test =  np.array(test_label, dtype=np.float32) 

    y_train = y_train.flatten()
    y_test = y_test.flatten()

    y_train_onehot = to_categorical(y_train)
    y_test_onehot = to_categorical(y_test)


    loss_train = cce(constant(y_train_onehot), constant(prob_train), from_logits=False).numpy()
    loss_test = cce(constant(y_test_onehot), constant(prob_test), from_logits=False).numpy()   
    
    attack_types = [
    AttackType.THRESHOLD_ATTACK,
    AttackType.LOGISTIC_REGRESSION
    ]
    
    attack_input = AttackInputData(
      logits_train = logits_train,
      logits_test = logits_test,
      loss_train = loss_train,
      loss_test = loss_test,
      labels_train = y_train.astype(np.int8),
      labels_test = y_test.astype(np.int8)
    )
    slicing_spec = SlicingSpec(
    entire_dataset = True,
    by_class = True,
    by_percentiles = False,
    by_classification_correctness = True)
    
    attacks_result = mia.run_attacks(attack_input=attack_input,
                                 slicing_spec=slicing_spec,
                                 attack_types=attack_types)
    
    print(attacks_result.summary(by_slices=True))
    
    print(plotting.plot_roc_curve(attacks_result.get_result_with_max_auc().roc_curve))

# %%
membership_inference_attack(nn2, X_train_transform, X_test_transform, y_train, y_test)
# Out:
# Predict on train...
# Predict on test...
# Apply softmax to get probabilities from logits...
# Compute losses...
# loss train (361944,)
# loss test (61503,)
# y train (361944, 2)
# y test (61503, 2)
# Best-performing attacks over all slices
#   THRESHOLD_ATTACK (with 180972 training and 4949 test examples) achieved an AUC of 0.92 on slice CLASS=1
#   THRESHOLD_ATTACK (with 180972 training and 4949 test examples) achieved an advantage of 0.68 on slice CLASS=1
#
# Best-performing attacks over slice: "Entire dataset"
#   LOGISTIC_REGRESSION (with 61503 training and 61503 test examples) achieved an AUC of 0.72
#   LOGISTIC_REGRESSION (with 61503 training and 61503 test examples) achieved an advantage of 0.43
#
# Best-performing attacks over slice: "CLASS=0"
#   THRESHOLD_ATTACK (with 180972 training and 56554 test examples) achieved an AUC of 0.52
#   THRESHOLD_ATTACK (with 180972 training and 56554 test examples) achieved an advantage of 0.03
#
# Best-performing attacks over slice: "CLASS=1"
#   THRESHOLD_ATTACK (with 180972 training and 4949 test examples) achieved an AUC of 0.92
#   THRESHOLD_ATTACK (with 180972 training and 4949 test examples) achieved an advantage of 0.68
#
# Best-performing attacks over slice: "CORRECTLY_CLASSIFIED=True"
#   LOGISTIC_REGRESSION (with 52395 training and 52395 test examples) achieved an AUC of 0.74
#   LOGISTIC_REGRESSION (with 52395 training and 52395 test examples) achieved an advantage of 0.48
#
# Best-performing attacks over slice: "CORRECTLY_CLASSIFIED=False"
#   LOGISTIC_REGRESSION (with 9108 training and 9108 test examples) achieved an AUC of 0.67
#   LOGISTIC_REGRESSION (with 9108 training and 9108 test examples) achieved an advantage of 0.24
# Figure(432x288)

# %%
membership_inference_attack(nn3, X_train_transform, X_test_transform, y_train, y_test)
# Out:
# Predict on train...
# Predict on test...
# Apply softmax to get probabilities from logits...
# Compute losses...
# loss train (361944,)
# loss test (61503,)
# y train (361944, 2)
# y test (61503, 2)
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 42438 training and 42438 test examples) achieved an AUC of 0.74 on slice CORRECTLY_CLASSIFIED=True
#   LOGISTIC_REGRESSION (with 42438 training and 42438 test examples) achieved an advantage of 0.47 on slice CORRECTLY_CLASSIFIED=True
#
# Best-performing attacks over slice: "Entire dataset"
#   LOGISTIC_REGRESSION (with 61503 training and 61503 test examples) achieved an AUC of 0.67
#   LOGISTIC_REGRESSION (with 61503 training and 61503 test examples) achieved an advantage of 0.37
#
# Best-performing attacks over slice: "CLASS=0"
#   THRESHOLD_ATTACK (with 180972 training and 56554 test examples) achieved an AUC of 0.50
#   LOGISTIC_REGRESSION (with 56554 training and 56554 test examples) achieved an advantage of 0.01
#
# Best-performing attacks over slice: "CLASS=1"
#   THRESHOLD_ATTACK (with 180972 training and 4949 test examples) achieved an AUC of 0.69
#   THRESHOLD_ATTACK (with 180972 training and 4949 test examples) achieved an advantage of 0.27
#
# Best-performing attacks over slice: "CORRECTLY_CLASSIFIED=True"
#   LOGISTIC_REGRESSION (with 42438 training and 42438 test examples) achieved an AUC of 0.74
#   LOGISTIC_REGRESSION (with 42438 training and 42438 test examples) achieved an advantage of 0.47
#
# Best-performing attacks over slice: "CORRECTLY_CLASSIFIED=False"
#   LOGISTIC_REGRESSION (with 19065 training and 19065 test examples) achieved an AUC of 0.62
#   LOGISTIC_REGRESSION (with 19065 training and 19065 test examples) achieved an advantage of 0.20
# Figure(432x288)

# %% [markdown]
# ## Changing model architecture to  Binary from Multi Categorical Classification

# %%
mod1 = make_model(logits=True, last_nodes=1)
mod1.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True), optimizer='adam', metrics=['accuracy'])

# %%
history = mod1.fit(X_train_transform, y_train, epochs=50, batch_size=256, validation_data=(X_val_transform, y_val))
# Out:
# Epoch 1/50
# 1414/1414 [==============================] - 13s 8ms/step - loss: 0.5946 - accuracy: 0.6658 - val_loss: 0.5205 - val_accuracy: 0.8081
# Epoch 2/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.5319 - accuracy: 0.7202 - val_loss: 0.4939 - val_accuracy: 0.8267
# Epoch 3/50
# 1414/1414 [==============================] - 10s 7ms/step - loss: 0.5080 - accuracy: 0.7412 - val_loss: 0.5033 - val_accuracy: 0.8098
# Epoch 4/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.4903 - accuracy: 0.7538 - val_loss: 0.4963 - val_accuracy: 0.8172
# Epoch 5/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.4772 - accuracy: 0.7625 - val_loss: 0.4760 - val_accuracy: 0.8292
# Epoch 6/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.4633 - accuracy: 0.7702 - val_loss: 0.4830 - val_accuracy: 0.8272
# Epoch 7/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.4527 - accuracy: 0.7779 - val_loss: 0.4571 - val_accuracy: 0.8384
# Epoch 8/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.4428 - accuracy: 0.7828 - val_loss: 0.4735 - val_accuracy: 0.8341
# Epoch 9/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.4330 - accuracy: 0.7877 - val_loss: 0.4587 - val_accuracy: 0.8407
# Epoch 10/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.4256 - accuracy: 0.7916 - val_loss: 0.4323 - val_accuracy: 0.8513
# Epoch 11/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.4179 - accuracy: 0.7953 - val_loss: 0.4419 - val_accuracy: 0.8518
# Epoch 12/50
# 1414/1414 [==============================] - 11s 7ms/step - loss: 0.4111 - accuracy: 0.7996 - val_loss: 0.4574 - val_accuracy: 0.8384
# Epoch 13/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.4043 - accuracy: 0.8029 - val_loss: 0.4349 - val_accuracy: 0.8511
# Epoch 14/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3981 - accuracy: 0.8073 - val_loss: 0.4327 - val_accuracy: 0.8463
# Epoch 15/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3938 - accuracy: 0.8092 - val_loss: 0.4208 - val_accuracy: 0.8506
# Epoch 16/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3904 - accuracy: 0.8119 - val_loss: 0.4131 - val_accuracy: 0.8592
# Epoch 17/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3863 - accuracy: 0.8130 - val_loss: 0.4025 - val_accuracy: 0.8650
# Epoch 18/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3815 - accuracy: 0.8161 - val_loss: 0.4053 - val_accuracy: 0.8609
# Epoch 19/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3781 - accuracy: 0.8182 - val_loss: 0.4113 - val_accuracy: 0.8595
# Epoch 20/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3740 - accuracy: 0.8202 - val_loss: 0.4167 - val_accuracy: 0.8558
# Epoch 21/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3709 - accuracy: 0.8229 - val_loss: 0.4056 - val_accuracy: 0.8574
# Epoch 22/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3681 - accuracy: 0.8236 - val_loss: 0.3976 - val_accuracy: 0.8655
# Epoch 23/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3661 - accuracy: 0.8254 - val_loss: 0.3918 - val_accuracy: 0.8656
# Epoch 24/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3628 - accuracy: 0.8274 - val_loss: 0.4175 - val_accuracy: 0.8545
# Epoch 25/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3615 - accuracy: 0.8278 - val_loss: 0.4191 - val_accuracy: 0.8525
# Epoch 26/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3588 - accuracy: 0.8291 - val_loss: 0.4010 - val_accuracy: 0.8620
# Epoch 27/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3560 - accuracy: 0.8312 - val_loss: 0.4440 - val_accuracy: 0.8406
# Epoch 28/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3539 - accuracy: 0.8317 - val_loss: 0.3928 - val_accuracy: 0.8663
# Epoch 29/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3530 - accuracy: 0.8334 - val_loss: 0.4066 - val_accuracy: 0.8592
# Epoch 30/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3512 - accuracy: 0.8344 - val_loss: 0.3949 - val_accuracy: 0.8629
# Epoch 31/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3473 - accuracy: 0.8364 - val_loss: 0.3800 - val_accuracy: 0.8723
# Epoch 32/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3462 - accuracy: 0.8374 - val_loss: 0.3833 - val_accuracy: 0.8695
# Epoch 33/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3448 - accuracy: 0.8386 - val_loss: 0.3950 - val_accuracy: 0.8660
# Epoch 34/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3441 - accuracy: 0.8373 - val_loss: 0.3951 - val_accuracy: 0.8639
# Epoch 35/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3437 - accuracy: 0.8385 - val_loss: 0.3967 - val_accuracy: 0.8635
# Epoch 36/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3414 - accuracy: 0.8395 - val_loss: 0.4018 - val_accuracy: 0.8618
# Epoch 37/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3398 - accuracy: 0.8412 - val_loss: 0.3944 - val_accuracy: 0.8635
# Epoch 38/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3382 - accuracy: 0.8416 - val_loss: 0.4044 - val_accuracy: 0.8602
# Epoch 39/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3389 - accuracy: 0.8405 - val_loss: 0.4174 - val_accuracy: 0.8515
# Epoch 40/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3358 - accuracy: 0.8433 - val_loss: 0.3719 - val_accuracy: 0.8752
# Epoch 41/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3349 - accuracy: 0.8434 - val_loss: 0.3854 - val_accuracy: 0.8672
# Epoch 42/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3349 - accuracy: 0.8441 - val_loss: 0.3722 - val_accuracy: 0.8763
# Epoch 43/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3340 - accuracy: 0.8436 - val_loss: 0.3914 - val_accuracy: 0.8657
# Epoch 44/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3320 - accuracy: 0.8449 - val_loss: 0.3775 - val_accuracy: 0.8735
# Epoch 45/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3312 - accuracy: 0.8454 - val_loss: 0.3746 - val_accuracy: 0.8766
# Epoch 46/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3301 - accuracy: 0.8461 - val_loss: 0.4023 - val_accuracy: 0.8611
# Epoch 47/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3288 - accuracy: 0.8469 - val_loss: 0.3818 - val_accuracy: 0.8707
# Epoch 48/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3284 - accuracy: 0.8472 - val_loss: 0.3739 - val_accuracy: 0.8760
# Epoch 49/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3269 - accuracy: 0.8479 - val_loss: 0.3619 - val_accuracy: 0.8795
# Epoch 50/50
# 1414/1414 [==============================] - 11s 8ms/step - loss: 0.3264 - accuracy: 0.8489 - val_loss: 0.3898 - val_accuracy: 0.8678

# %% [markdown]
# ## DP-Binary

# %%
noise_multiplier=.01
l2_norm_clip=1
num_microbatches=1

dp = DPKerasAdamOptimizer(
            l2_norm_clip=l2_norm_clip,
            noise_multiplier=noise_multiplier,num_microbatches=num_microbatches)

mod2 = make_model(logits=True, last_nodes=1)
mod2.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True), optimizer=dp, metrics=['accuracy'])
history = mod2.fit(X_train_transform, y_train, epochs=50, batch_size=256, validation_data=(X_val_transform, y_val))
# Out:
# Epoch 1/50
# 1414/1414 [==============================] - 27s 14ms/step - loss: 0.6361 - accuracy: 0.6305 - val_loss: 0.6145 - val_accuracy: 0.7531
# Epoch 2/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5770 - accuracy: 0.6783 - val_loss: 0.6245 - val_accuracy: 0.7411
# Epoch 3/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5656 - accuracy: 0.6915 - val_loss: 0.6203 - val_accuracy: 0.7426
# Epoch 4/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5586 - accuracy: 0.6987 - val_loss: 0.6171 - val_accuracy: 0.7440
# Epoch 5/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5545 - accuracy: 0.7047 - val_loss: 0.6225 - val_accuracy: 0.7397
# Epoch 6/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5507 - accuracy: 0.7075 - val_loss: 0.6141 - val_accuracy: 0.7451
# Epoch 7/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5475 - accuracy: 0.7104 - val_loss: 0.6222 - val_accuracy: 0.7445
# Epoch 8/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5455 - accuracy: 0.7125 - val_loss: 0.6185 - val_accuracy: 0.7463
# Epoch 9/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5450 - accuracy: 0.7126 - val_loss: 0.6255 - val_accuracy: 0.7448
# Epoch 10/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5418 - accuracy: 0.7150 - val_loss: 0.6064 - val_accuracy: 0.7566
# Epoch 11/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5398 - accuracy: 0.7163 - val_loss: 0.6069 - val_accuracy: 0.7560
# Epoch 12/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5393 - accuracy: 0.7181 - val_loss: 0.6093 - val_accuracy: 0.7531
# Epoch 13/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5377 - accuracy: 0.7192 - val_loss: 0.6116 - val_accuracy: 0.7529
# Epoch 14/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5373 - accuracy: 0.7201 - val_loss: 0.6077 - val_accuracy: 0.7539
# Epoch 15/50
# 1414/1414 [==============================] - 19s 14ms/step - loss: 0.5361 - accuracy: 0.7206 - val_loss: 0.6066 - val_accuracy: 0.7565
# Epoch 16/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5351 - accuracy: 0.7224 - val_loss: 0.6085 - val_accuracy: 0.7519
# Epoch 17/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5340 - accuracy: 0.7233 - val_loss: 0.6047 - val_accuracy: 0.7553
# Epoch 18/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5338 - accuracy: 0.7242 - val_loss: 0.6085 - val_accuracy: 0.7538
# Epoch 19/50
# 1414/1414 [==============================] - 18s 13ms/step - loss: 0.5331 - accuracy: 0.7246 - val_loss: 0.6076 - val_accuracy: 0.7518
# Epoch 20/50
# 1414/1414 [==============================] - 18s 13ms/step - loss: 0.5325 - accuracy: 0.7253 - val_loss: 0.5985 - val_accuracy: 0.7614
# Epoch 21/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5320 - accuracy: 0.7254 - val_loss: 0.6010 - val_accuracy: 0.7571
# Epoch 22/50
# 1414/1414 [==============================] - 18s 13ms/step - loss: 0.5310 - accuracy: 0.7263 - val_loss: 0.5934 - val_accuracy: 0.7555
# Epoch 23/50
# 1414/1414 [==============================] - 18s 13ms/step - loss: 0.5308 - accuracy: 0.7272 - val_loss: 0.6057 - val_accuracy: 0.7507
# Epoch 24/50
# 1414/1414 [==============================] - 18s 13ms/step - loss: 0.5301 - accuracy: 0.7274 - val_loss: 0.5949 - val_accuracy: 0.7576
# Epoch 25/50
# 1414/1414 [==============================] - 18s 13ms/step - loss: 0.5296 - accuracy: 0.7270 - val_loss: 0.6014 - val_accuracy: 0.7510
# Epoch 26/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5295 - accuracy: 0.7265 - val_loss: 0.6011 - val_accuracy: 0.7569
# Epoch 27/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5288 - accuracy: 0.7274 - val_loss: 0.5923 - val_accuracy: 0.7637
# Epoch 28/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5276 - accuracy: 0.7286 - val_loss: 0.6033 - val_accuracy: 0.7541
# Epoch 29/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5276 - accuracy: 0.7283 - val_loss: 0.5941 - val_accuracy: 0.7635
# Epoch 30/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5274 - accuracy: 0.7292 - val_loss: 0.5990 - val_accuracy: 0.7567
# Epoch 31/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5275 - accuracy: 0.7287 - val_loss: 0.5999 - val_accuracy: 0.7579
# Epoch 32/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5274 - accuracy: 0.7280 - val_loss: 0.5997 - val_accuracy: 0.7559
# Epoch 33/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5274 - accuracy: 0.7288 - val_loss: 0.5929 - val_accuracy: 0.7642
# Epoch 34/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5264 - accuracy: 0.7291 - val_loss: 0.6063 - val_accuracy: 0.7570
# Epoch 35/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5267 - accuracy: 0.7287 - val_loss: 0.5996 - val_accuracy: 0.7616
# Epoch 36/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5268 - accuracy: 0.7290 - val_loss: 0.5862 - val_accuracy: 0.7710
# Epoch 37/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5264 - accuracy: 0.7298 - val_loss: 0.5973 - val_accuracy: 0.7610
# Epoch 38/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5254 - accuracy: 0.7302 - val_loss: 0.5884 - val_accuracy: 0.7716
# Epoch 39/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5249 - accuracy: 0.7301 - val_loss: 0.5878 - val_accuracy: 0.7695
# Epoch 40/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5243 - accuracy: 0.7313 - val_loss: 0.5982 - val_accuracy: 0.7571
# Epoch 41/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5246 - accuracy: 0.7310 - val_loss: 0.5884 - val_accuracy: 0.7699
# Epoch 42/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5239 - accuracy: 0.7321 - val_loss: 0.5957 - val_accuracy: 0.7661
# Epoch 43/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5241 - accuracy: 0.7307 - val_loss: 0.5805 - val_accuracy: 0.7720
# Epoch 44/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5246 - accuracy: 0.7307 - val_loss: 0.5873 - val_accuracy: 0.7665
# Epoch 45/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5240 - accuracy: 0.7312 - val_loss: 0.6009 - val_accuracy: 0.7585
# Epoch 46/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5230 - accuracy: 0.7317 - val_loss: 0.5954 - val_accuracy: 0.7658
# Epoch 47/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5228 - accuracy: 0.7313 - val_loss: 0.5968 - val_accuracy: 0.7639
# Epoch 48/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5234 - accuracy: 0.7311 - val_loss: 0.5960 - val_accuracy: 0.7676
# Epoch 49/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5226 - accuracy: 0.7307 - val_loss: 0.5870 - val_accuracy: 0.7723
# Epoch 50/50
# 1414/1414 [==============================] - 19s 13ms/step - loss: 0.5235 - accuracy: 0.7314 - val_loss: 0.5929 - val_accuracy: 0.7651

# %%
from copy import deepcopy
def membership_inference_attack_binary(model, X_train, X_test, train_label, test_label):
    X_train = deepcopy(X_train)
    X_test = deepcopy(X_test)
    train_label = deepcopy(train_label)
    test_label = deepcopy(test_label)
    
    print('Predict on train...')
    logits_train = model.predict(X_train)

    print('Predict on test...')
    logits_test = model.predict(X_test)

    print('Apply softmax to get probabilities from logits...')
    prob_train = special.expit(logits_train)
    prob_test = special.expit(logits_test)
    y_train_pred = np.argmax(prob_train)
    y_test_pred = np.argmax(prob_test)
    
    print('Compute losses...')
    bce = tf.keras.backend.binary_crossentropy
    constant = tf.keras.backend.constant

    y_train = np.array(train_label, dtype=np.float32) 
    y_test =  np.array(test_label, dtype=np.float32) 

    y_train = y_train.flatten()
    y_test = y_test.flatten()
    
    loss_train = bce(constant(y_train), constant(y_train_pred), from_logits=False).numpy()
    loss_test = bce(constant(y_test), constant(y_test_pred), from_logits=False).numpy()
    
    attack_types = [
    AttackType.THRESHOLD_ATTACK,
    AttackType.LOGISTIC_REGRESSION
    ]
    
    attack_input = AttackInputData(
      logits_train = logits_train,
      logits_test = logits_test,
      loss_train = loss_train,
      loss_test = loss_test,
      labels_train = y_train.astype(np.int8),
      labels_test = y_test.astype(np.int8)
    )
    slicing_spec = SlicingSpec(
    entire_dataset = True,
    by_class = True,
    by_percentiles = False,
    by_classification_correctness = True)
    
    attacks_result = mia.run_attacks(attack_input=attack_input,
                                 slicing_spec=slicing_spec,
                                 attack_types=attack_types)
    
    print(attacks_result.summary(by_slices=True))
    
    print(plotting.plot_roc_curve(attacks_result.get_result_with_max_auc().roc_curve))

# %%
membership_inference_attack_binary(mod1, X_train_transform, X_test_transform, y_train, y_test)
membership_inference_attack_binary(mod2, X_train_transform, X_test_transform, y_train, y_test)
# Out:
# Predict on train...
# Predict on test...
# Apply softmax to get probabilities from logits...
# Compute losses...
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 4949 training and 4949 test examples) achieved an AUC of 0.91 on slice CLASS=1
#   LOGISTIC_REGRESSION (with 4949 training and 4949 test examples) achieved an advantage of 0.66 on slice CORRECTLY_CLASSIFIED=False
#
# Best-performing attacks over slice: "Entire dataset"
#   LOGISTIC_REGRESSION (with 61503 training and 61503 test examples) achieved an AUC of 0.72
#   LOGISTIC_REGRESSION (with 61503 training and 61503 test examples) achieved an advantage of 0.45
#
# Best-performing attacks over slice: "CLASS=0"
#   LOGISTIC_REGRESSION (with 56554 training and 56554 test examples) achieved an AUC of 0.52
#   LOGISTIC_REGRESSION (with 56554 training and 56554 test examples) achieved an advantage of 0.03
#
# Best-performing attacks over slice: "CLASS=1"
#   LOGISTIC_REGRESSION (with 4949 training and 4949 test examples) achieved an AUC of 0.91
#   LOGISTIC_REGRESSION (with 4949 training and 4949 test examples) achieved an advantage of 0.66
#
# Best-performing attacks over slice: "CORRECTLY_CLASSIFIED=True"
#   LOGISTIC_REGRESSION (with 56554 training and 56554 test examples) achieved an AUC of 0.52
#   LOGISTIC_REGRESSION (with 56554 training and 56554 test examples) achieved an advantage of 0.03
#
# Best-performing attacks over slice: "CORRECTLY_CLASSIFIED=False"
#   LOGISTIC_REGRESSION (with 4949 training and 4949 test examples) achieved an AUC of 0.91
#   LOGISTIC_REGRESSION (with 4949 training and 4949 test examples) achieved an advantage of 0.66
# Figure(432x288)
# Predict on train...
# Predict on test...
# Apply softmax to get probabilities from logits...
# Compute losses...
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 61503 training and 61503 test examples) achieved an AUC of 0.72 on slice Entire dataset
#   LOGISTIC_REGRESSION (with 61503 training and 61503 test examples) achieved an advantage of 0.42 on slice Entire dataset
#
# Best-performing attacks over slice: "Entire dataset"
#   LOGISTIC_REGRESSION (with 61503 training and 61503 test examples) achieved an AUC of 0.72
#   LOGISTIC_REGRESSION (with 61503 training and 61503 test examples) achieved an advantage of 0.42
#
# Best-performing attacks over slice: "CLASS=0"
#   LOGISTIC_REGRESSION (with 56554 training and 56554 test examples) achieved an AUC of 0.51
#   LOGISTIC_REGRESSION (with 56554 training and 56554 test examples) achieved an advantage of 0.01
#
# Best-performing attacks over slice: "CLASS=1"
#   LOGISTIC_REGRESSION (with 4949 training and 4949 test examples) achieved an AUC of 0.68
#   LOGISTIC_REGRESSION (with 4949 training and 4949 test examples) achieved an advantage of 0.27
#
# Best-performing attacks over slice: "CORRECTLY_CLASSIFIED=True"
#   LOGISTIC_REGRESSION (with 56554 training and 56554 test examples) achieved an AUC of 0.50
#   LOGISTIC_REGRESSION (with 56554 training and 56554 test examples) achieved an advantage of 0.01
#
# Best-performing attacks over slice: "CORRECTLY_CLASSIFIED=False"
#   LOGISTIC_REGRESSION (with 4949 training and 4949 test examples) achieved an AUC of 0.66
#   LOGISTIC_REGRESSION (with 4949 training and 4949 test examples) achieved an advantage of 0.25
# Figure(432x288)
